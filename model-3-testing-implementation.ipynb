# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# %%
# Load the model
model = load_model("/kaggle/input/ahsan-model-3-testing-implementation/from_kaggle/model_3.h5", compile=False)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  batch_normalization_1 (Batc  (None, 22, 22, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 256)               7930112
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 8,319,746
# Trainable params: 8,319,106
# Non-trainable params: 640
# _________________________________________________________________

# %%
# Load the labels
class_names = ["happy", "sad"]

# %%
# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(48, 48, 1), dtype=np.float32)

# %%
# Replace this with the path to your image
image = Image.open("/kaggle/input/ahsan-model-3-testing-implementation/from_kaggle/dataset/sad/PrivateTest_568359.jpg").convert("RGB")

# %% [markdown]
# Since the testing is no test folder, the expected expression recognition should be **sad**

# %%
gray_image = image.convert("L")

# %%
# resizing the image to be at least 48x48 and then cropping from the center
size = (48, 48)
image = ImageOps.fit(gray_image, size, Image.Resampling.LANCZOS)

# %%
# turn the image into a numpy array
image_array = np.asarray(image)

# %%
image_array.shape
# Out:
# (48, 48)

# %%
# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# %%
# Load the image into the array
data[:, :, 0] = normalized_image_array

# %%
data_tensor = tf.convert_to_tensor(data, dtype=tf.float32)

# %%
data_tensor = tf.expand_dims(data_tensor, axis=0)

# %%
data_tensor.shape
# Out:
# TensorShape([1, 48, 48, 1])

# %%
# Predicts the model
prediction = model.predict(data_tensor)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
# Print prediction and confidence score
print("Class:", class_name, end=" ")
print("Confidence Score:", confidence_score)
# Out:
# Class: sad Confidence Score: 0.997088

# %% [markdown]
# The expected recognition is already true

# %% [markdown]
# ## Testing for another classes

# %%
image2 = Image.open("/kaggle/input/ahsan-model-3-testing-implementation/from_kaggle/dataset/happy/PrivateTest_61167984.jpg").convert("RGB")

# %% [markdown]
# The expected recognition should be **happy**

# %%
gray_image = image2.convert("L")

# %%
size = (48, 48)
image2 = ImageOps.fit(gray_image, size, Image.Resampling.LANCZOS)

# %%
image_array2 = np.asarray(image2)

# %%
image_array2.shape
# Out:
# (48, 48)

# %%
normalized_image_array2 = (image_array2.astype(np.float32) / 127.5) - 1

# %%
data[:, :, 0] = normalized_image_array2

# %%
data_tensor2 = tf.convert_to_tensor(data, dtype=tf.float32)

# %%
data_tensor2 = tf.expand_dims(data_tensor2, axis=0)

# %%
data_tensor2.shape
# Out:
# TensorShape([1, 48, 48, 1])

# %%
# Predicts the model
prediction = model.predict(data_tensor2)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
# Print prediction and confidence score
print("Class:", class_name, end=" ")
print("Confidence Score:", confidence_score)
# Out:
# Class: happy Confidence Score: 0.7747352

# %% [markdown]
# The expected output already correct
